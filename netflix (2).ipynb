# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('netflix_titles.tsv', sep='\t')
df.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
# 2                             United States  September 8, 2018          2013
# 3                             United States  September 8, 2018          2016
# 4                             United States  September 8, 2017          2017
#
#      rating  duration                           listed_in  \
# 0     TV-PG    90 min  Children &amp; Family Movies, Comedies
# 1     TV-MA    94 min                     Stand-Up Comedy
# 2  TV-Y7-FV  1 Season                            Kids&#39; TV
# 3     TV-Y7  1 Season                            Kids&#39; TV
# 4     TV-14    99 min                            Comedies
#
#                                          description
# 0  Before planning an awesome wedding for his gra...
# 1  Jandino Asporaat riffs on the challenges of ra...
# 2  With the help of three human allies, the Autob...
# 3  When a prison ship crash unleashes hundreds of...
# 4  When nerdy high schooler Dani finally attracts...

# %%
df.shape
# Out:
# (6234, 12)

# %%
df['type'].unique()
# Out:
# array([&#39;Movie&#39;, &#39;TV Show&#39;], dtype=object)

# %%
df['type'].value_counts()
# Out:
# Movie      4265
# TV Show    1969
# Name: type, dtype: int64

# %%
sns.set(style="darkgrid")
ax = sns.countplot(x='type', data=df)
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
len(df['country'].unique())
# Out:
# 555

# %%
l=dict(df['country'].value_counts()[:21])
print(l)
list_pays=list(l.keys())

print(list_pays)
# Out:
# {&#39;United States&#39;: 2032, &#39;India&#39;: 777, &#39;United Kingdom&#39;: 348, &#39;Japan&#39;: 176, &#39;Canada&#39;: 141, &#39;South Korea&#39;: 136, &#39;Spain&#39;: 117, &#39;France&#39;: 90, &#39;Mexico&#39;: 83, &#39;Turkey&#39;: 79, &#39;Australia&#39;: 71, &#39;Taiwan&#39;: 69, &#39;Hong Kong&#39;: 51, &#39;Thailand&#39;: 50, &#39;United Kingdom, United States&#39;: 50, &#39;Egypt&#39;: 50, &#39;Brazil&#39;: 50, &#39;China&#39;: 50, &#39;Indonesia&#39;: 44, &#39;Philippines&#39;: 44, &#39;Germany&#39;: 40}
# [&#39;United States&#39;, &#39;India&#39;, &#39;United Kingdom&#39;, &#39;Japan&#39;, &#39;Canada&#39;, &#39;South Korea&#39;, &#39;Spain&#39;, &#39;France&#39;, &#39;Mexico&#39;, &#39;Turkey&#39;, &#39;Australia&#39;, &#39;Taiwan&#39;, &#39;Hong Kong&#39;, &#39;Thailand&#39;, &#39;United Kingdom, United States&#39;, &#39;Egypt&#39;, &#39;Brazil&#39;, &#39;China&#39;, &#39;Indonesia&#39;, &#39;Philippines&#39;, &#39;Germany&#39;]

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        1969
# cast             570
# country          476
# date_added        11
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        1969
# cast             570
# country          476
# date_added        11
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
pays=list_pays




contenu=['']*len(pays)
dictionn=dict(zip(pays,contenu))



for c in pays:
  datapays=df[df['country']==c]
  for p in datapays['listed_in']:
    dictionn[c] +=str(p)

# %%
pays_centenu=[]
for key, values in dictionn.items():
    pays_centenu.append([key,values])



output1=[]
output2=[]
output3=[]
for i in range(21):
    output2+=[pays_centenu[i][0]]
    output3+=[pays_centenu[i][1]]
d={'pays':output2,'contenu':output3}

df_pays = pd.DataFrame(d)
df_pays.index += 1 
df_pays
# Out:
#                              pays  \
# 1                   United States
# 2                           India
# 3                  United Kingdom
# 4                           Japan
# 5                          Canada
# 6                     South Korea
# 7                           Spain
# 8                          France
# 9                          Mexico
# 10                         Turkey
# 11                      Australia
# 12                         Taiwan
# 13                      Hong Kong
# 14                       Thailand
# 15  United Kingdom, United States
# 16                          Egypt
# 17                         Brazil
# 18                          China
# 19                      Indonesia
# 20                    Philippines
# 21                        Germany
#
#                                               contenu
# 1   Kids&#39; TVKids&#39; TVComediesDocuseries, Science &amp; ...
# 2   Dramas, International Movies, ThrillersComedie...
# 3   Stand-Up ComedyDramas, Independent MoviesDocum...
# 4   Anime Series, International TV ShowsAnime Seri...
# 5   Horror MoviesComedies, International MoviesChi...
# 6   Dramas, International MoviesInternational TV S...
# 7   Crime TV Shows, International TV Shows, Spanis...
# 8   International TV Shows, TV Dramas, TV Thriller...
# 9   Crime TV Shows, International TV Shows, Spanis...
# 10  Comedies, International MoviesComedies, Intern...
# 11  International TV Shows, TV Comedies, TV Dramas...
# 12  Crime TV Shows, International TV Shows, TV Dra...
# 13  Dramas, Independent Movies, International Movi...
# 14  Horror Movies, International MoviesComedies, I...
# 15  Action &amp; AdventureIndependent Movies, Internat...
# 16  Action &amp; Adventure, Comedies, International Mo...
# 17  Dramas, Independent Movies, International Movi...
# 18  Action &amp; Adventure, International Movies, Sci-...
# 19  Dramas, International MoviesComedies, Internat...
# 20  Dramas, International MoviesAction &amp; Adventure...
# 21  Action &amp; Adventure, Comedies, International Mo...

# %%
df['rating'].unique()
# Out:
# array([&#39;TV-PG&#39;, &#39;TV-MA&#39;, &#39;TV-Y7-FV&#39;, &#39;TV-Y7&#39;, &#39;TV-14&#39;, &#39;R&#39;, &#39;TV-Y&#39;, &#39;NR&#39;,
#        &#39;PG-13&#39;, &#39;TV-G&#39;, &#39;PG&#39;, &#39;G&#39;, nan, &#39;UR&#39;, &#39;NC-17&#39;], dtype=object)

# %%
sns.set(style="darkgrid")
x=plt.subplots(1,1,figsize = (15,5))
sns.countplot(x='rating', data=df,order=df['rating'].value_counts().index[0:15])
# Out:
# &lt;matplotlib.axes._subplots.AxesSubplot at 0x2b84fcccd30&gt;
# &lt;Figure size 1080x360 with 1 Axes&gt;

# %%
df=df.dropna(subset=['country'])
country=df['country'].unique()
c=[]
for i in range(100):
    ele=list(country[i].split(','))
    for item in ele:
        c.append(item)
list_final=c
output = []
for x in list_final:

    if x not in output:
        output.append(x)
print(output)
# Out:
# [&#39;United States&#39;, &#39; India&#39;, &#39; South Korea&#39;, &#39; China&#39;, &#39;United Kingdom&#39;, &#39;Spain&#39;, &#39;Bulgaria&#39;, &#39; United States&#39;, &#39; Spain&#39;, &#39; Canada&#39;, &#39;Chile&#39;, &#39; United Kingdom&#39;, &#39; Denmark&#39;, &#39; Sweden&#39;, &#39;Netherlands&#39;, &#39; Belgium&#39;, &#39;France&#39;, &#39; Uruguay&#39;, &#39;&#39;, &#39;Thailand&#39;, &#39;China&#39;, &#39;Belgium&#39;, &#39; France&#39;, &#39;India&#39;, &#39;Pakistan&#39;, &#39;Canada&#39;, &#39;South Korea&#39;, &#39;Denmark&#39;, &#39;Turkey&#39;, &#39;Brazil&#39;, &#39; Italy&#39;, &#39; Netherlands&#39;, &#39;Indonesia&#39;, &#39;Ireland&#39;, &#39;Hong Kong&#39;, &#39; Morocco&#39;, &#39;Mexico&#39;, &#39; Mexico&#39;, &#39;Vietnam&#39;, &#39; Argentina&#39;, &#39;Nigeria&#39;, &#39;Japan&#39;, &#39; Germany&#39;, &#39; Greece&#39;, &#39;Norway&#39;, &#39; Ireland&#39;, &#39; Switzerland&#39;, &#39; United Arab Emirates&#39;, &#39; Japan&#39;, &#39;Lebanon&#39;, &#39;Cambodia&#39;, &#39;Russia&#39;, &#39;Poland&#39;, &#39;Israel&#39;, &#39;Italy&#39;, &#39;Germany&#39;, &#39; Australia&#39;, &#39; Brazil&#39;, &#39; Portugal&#39;, &#39;United Arab Emirates&#39;, &#39;Egypt&#39;, &#39;Taiwan&#39;, &#39; Austria&#39;, &#39;Australia&#39;, &#39;Czech Republic&#39;, &#39; Senegal&#39;, &#39; Soviet Union&#39;, &#39;Argentina&#39;, &#39; Hong Kong&#39;, &#39; Israel&#39;, &#39; Peru&#39;, &#39; Norway&#39;, &#39;Switzerland&#39;, &#39; Ukraine&#39;, &#39;Malaysia&#39;, &#39; South Africa&#39;, &#39; Nepal&#39;, &#39;Philippines&#39;, &#39; Indonesia&#39;, &#39; Poland&#39;, &#39; Serbia&#39;]

# %%
plt.figure(figsize=(12,10))
sns.set(style="darkgrid")
ax = sns.countplot(y="release_year", data=df, palette="Set2", order=df['release_year'].value_counts().index[0:15])
# Out:
# &lt;Figure size 864x720 with 1 Axes&gt;

# %%
netflix_shows=df[df['type']=='TV Show']
df_date= netflix_shows[['date_added']].dropna()
df_date['year'] = df_date['date_added'].apply(lambda x : x.split(', ')[-1])
df_date['month'] = df_date['date_added'].apply(lambda x : x.lstrip().split(' ')[0])
df_date
# Out:
#              date_added  year      month
# 2     September 8, 2018  2018  September
# 3     September 8, 2018  2018  September
# 5     September 8, 2017  2017  September
# 8     September 8, 2017  2017  September
# 39    September 6, 2019  2019  September
# ...                 ...   ...        ...
# 6218     April 10, 2019  2019      April
# 6219      April 1, 2019  2019      April
# 6220      April 1, 2016  2016      April
# 6221      April 1, 2016  2016      April
# 6222      April 1, 2014  2014      April
#
# [1679 rows x 3 columns]

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'][::-1]
df = df_date.groupby('year')
df=df['month'].value_counts().unstack().fillna(0)[month_order].T

# %%
plt.figure(figsize=(10, 7), dpi=200)
plt.pcolor(df, cmap='afmhot_r', edgecolors='white', linewidths=2) # heatmap
plt.xticks(np.arange(0.5, len(df.columns), 1), df.columns, fontsize=7, fontfamily='serif')
plt.yticks(np.arange(0.5, len(df.index), 1), df.index, fontsize=7, fontfamily='serif')

plt.title('Netflix Contents Update', fontsize=12, fontfamily='calibri', fontweight='bold', position=(0.20, 1.0+0.02))
cbar = plt.colorbar()

cbar.ax.tick_params(labelsize=8) 
cbar.ax.minorticks_on()
plt.show()
# Out:
# &lt;Figure size 2000x1400 with 2 Axes&gt;

# %%
df_movies=df[df['type']=='Movie']

# %%
df_movies['duration']=df_movies['duration'].str.replace(' min','')
df_movies['duration']=df_movies['duration'].astype(str).astype(int)
sns.set(style="darkgrid")
sns.kdeplot(data=df_movies['duration'], shade=True)
# Out:
# &lt;matplotlib.axes._subplots.AxesSubplot at 0x2b85196beb0&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;
