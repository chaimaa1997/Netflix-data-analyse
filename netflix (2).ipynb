# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('netflix_titles.tsv', sep='\t')
df.head()
# Out:
#     show_id  ...                                        description
# 0  81145628  ...  Before planning an awesome wedding for his gra...
# 1  80117401  ...  Jandino Asporaat riffs on the challenges of ra...
# 2  70234439  ...  With the help of three human allies, the Autob...
# 3  80058654  ...  When a prison ship crash unleashes hundreds of...
# 4  80125979  ...  When nerdy high schooler Dani finally attracts...
#
# [5 rows x 12 columns]

# %%
df.shape
# Out:
# (6234, 12)

# %%
df['type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
df['type'].value_counts()
# Out:
# Movie      4265
# TV Show    1969
# Name: type, dtype: int64

# %%
len(df['country'].unique())
# Out:
# 555

# %%
l=dict(df['country'].value_counts()[:21])
print(l)
list_pays=list(l.keys())

print(list_pays)
# Out:
# {'United States': 2032, 'India': 777, 'United Kingdom': 348, 'Japan': 176, 'Canada': 141, 'South Korea': 136, 'Spain': 117, 'France': 90, 'Mexico': 83, 'Turkey': 79, 'Australia': 71, 'Taiwan': 69, 'Hong Kong': 51, 'United Kingdom, United States': 50, 'China': 50, 'Brazil': 50, 'Thailand': 50, 'Egypt': 50, 'Philippines': 44, 'Indonesia': 44, 'Germany': 40}
# ['United States', 'India', 'United Kingdom', 'Japan', 'Canada', 'South Korea', 'Spain', 'France', 'Mexico', 'Turkey', 'Australia', 'Taiwan', 'Hong Kong', 'United Kingdom, United States', 'China', 'Brazil', 'Thailand', 'Egypt', 'Philippines', 'Indonesia', 'Germany']

# %%
df.isna().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# 0

# %%
for s in df['country']:
  try:
    s=str(s) 
  except:
    print(s)

# %%
pays=list_pays
print(pays)



contenu=['']*len(pays)
dictionn=dict(zip(pays,contenu))
print(dictionn)


for c in pays:
  datapays=df[df['country']==c]
  for p in datapays['listed_in']:
    dictionn[c] +=str(p)


print(dictionn)
# Out:
# ['United States', 'India', 'United Kingdom', 'Japan', 'Canada', 'South Korea', 'Spain', 'France', 'Mexico', 'Turkey', 'Australia', 'Taiwan', 'Hong Kong', 'United Kingdom, United States', 'China', 'Brazil', 'Thailand', 'Egypt', 'Philippines', 'Indonesia', 'Germany']
# {'United States': '', 'India': '', 'United Kingdom': '', 'Japan': '', 'Canada': '', 'South Korea': '', 'Spain': '', 'France': '', 'Mexico': '', 'Turkey': '', 'Australia': '', 'Taiwan': '', 'Hong Kong': '', 'United Kingdom, United States': '', 'China': '', 'Brazil': '', 'Thailand': '', 'Egypt': '', 'Philippines': '', 'Indonesia': '', 'Germany': ''}
MoviesDramas, Romantic Movies, Sci-Fi & FantasyAction & Adventure, Romantic MoviesKids' TVAction & Adventure, ComediesIndependent Movies, ThrillersHorror Movies, ThrillersComedies, Cult Movies, Horror MoviesHorror MoviesHorror Movies, Independent Movies, ThrillersDramas, ThrillersAction & AdventureDramas, Independent MoviesDocuseries, Reality TVKids' TVComedies, Horror MoviesDocumentaries, Sports MoviesClassic Movies, Comedies, Independent MoviesDocumentaries, LGBTQ Movies, Music & MusicalsDocumentariesStand-Up ComedyDramas, Romantic MoviesDramas, ThrillersReality TVStand-Up ComedyStand-Up ComedyChildren & Family Movies, ComediesDocumentaries, Music & MusicalsDocumentariesStand-Up ComedyKids' TVHorror MoviesDocumentaries, LGBTQ MoviesComedies, Dramas, Independent MoviesKids' TV, TV Action & Adventure, TV DramasChildren & Family MoviesHorror Movies, ThrillersChildren & Family Movies, ComediesStand-Up ComedyDocumentariesHorror MoviesDramas, Romantic Movies, Sports MoviesDocumentariesAnime Series, Crime TV ShowsChildren & Family MoviesHorror MoviesHorror MoviesSt ...

# %%
pays_centenu=[]
for key, values in dictionn.items():
    pays_centenu.append([key,values])



output1=[]
output2=[]
output3=[]
for i in range(21):
    output2+=[pays_centenu[i][0]]
    output3+=[pays_centenu[i][1]]
d={'pays':output2,'contenu':output3}

df_pays = pd.DataFrame(d)
df_pays.index += 1 
df_pays
# Out:
#                              pays                                            contenu
# 1                   United States  Kids' TVKids' TVComediesDocuseries, Science & ...
# 2                           India  Dramas, International Movies, ThrillersComedie...
# 3                  United Kingdom  Stand-Up ComedyDramas, Independent MoviesDocum...
# 4                           Japan  Anime Series, International TV ShowsAnime Seri...
# 5                          Canada  Horror MoviesComedies, International MoviesChi...
# 6                     South Korea  Dramas, International MoviesInternational TV S...
# 7                           Spain  Crime TV Shows, International TV Shows, Spanis...
# 8                          France  International TV Shows, TV Dramas, TV Thriller...
# 9                          Mexico  Crime TV Shows, International TV Shows, Spanis...
# 10                         Turkey  Comedies, International MoviesComedies, Intern...
# 11                      Australia  International TV Shows, TV Comedies, TV Dramas...
# 12                         Taiwan  Crime TV Shows, International TV Shows, TV Dra...
# 13                      Hong Kong  Dramas, Independent Movies, International Movi...
# 14  United Kingdom, United States  Action & AdventureIndependent Movies, Internat...
# 15                          China  Action & Adventure, International Movies, Sci-...
# 16                         Brazil  Dramas, Independent Movies, International Movi...
# 17                       Thailand  Horror Movies, International MoviesComedies, I...
# 18                          Egypt  Action & Adventure, Comedies, International Mo...
# 19                    Philippines  Dramas, International MoviesAction & Adventure...
# 20                      Indonesia  Dramas, International MoviesComedies, Internat...
# 21                        Germany  Action & Adventure, Comedies, International Mo...
